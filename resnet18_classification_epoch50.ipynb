# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import DataLoader, random_split, ConcatDataset
from torchvision.utils import save_image
import numpy as np
import matplotlib.pyplot as plt
import os
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

BATCH_SIZE = 4
EPOCHS = 50
# Out:
# cuda

# %%
transform = transforms.Compose(
    [transforms.Resize((224,224)),
    transforms.ToTensor(),
     transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))]
)


# Data Load
image_dataset = torchvision.datasets.ImageFolder(root="/home/iai/Desktop/Jeewon/Seminar/20230112_MVtecAD/data/simpleclassification_good_bad_aug/dataset", transform = transform)
print(f'Entire classes : {image_dataset.classes}')
print(f'Size of Entire classes : {len(image_dataset)}')
# Out:
# Entire classes : ['bad', 'good']
# Size of Entire classes : 8192

# %%
train_size = int(0.8 * len(image_dataset))
test_size = len(image_dataset) - train_size

train_dataset, test_dataset = random_split(image_dataset, [train_size, test_size])


print(f'Size of entire dataset : {len(image_dataset)}')
print(f'Size of train dataset : {len(train_dataset)}')
print(f'Size of train dataset : {len(test_dataset)}')

train_loader = DataLoader(train_dataset, batch_size = BATCH_SIZE, shuffle = True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size = BATCH_SIZE, shuffle = False, num_workers=2)


def imshow(img):
    img = img / 2 + 0.5
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)))
    plt.show()
# Out:
# Size of entire dataset : 8192
# Size of train dataset : 6553
# Size of train dataset : 1639

# %%
dataiter = iter(train_loader)
images, labels = next(dataiter)

imshow(torchvision.utils.make_grid(images))
print(images.shape)
# Out:
# torch.Size([4, 3, 224, 224])

# %%
dataiter = iter(test_loader)
images, labels = next(dataiter)

imshow(torchvision.utils.make_grid(images))
print(images.shape)
# Out:
# torch.Size([4, 3, 224, 224])

# %%
criterion = nn.CrossEntropyLoss()

loss_list = []

def train(model, train_loader, optimizer, log_interval):
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(device)
        label = label.to(device)
        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()
        loss_list.append(loss.item())

        
        if batch_idx % 500 == 0:
            print("Train Epoch: {} [{}({:.0f}%)]\tTrain Loss : {:.6f}".format(
                EPOCHS, batch_idx * len(image), 100. * batch_idx / len(train_loader), loss.item()
            ))

# %%
acc_list = []
accuracy = 0.0

def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    # correct = 0
    
    with torch.no_grad():
      n_correct = 0
      n_samples = 0
      n_class_correct = [0 for i in range(2)]
      n_class_samples = [0 for i in range(2)]
      for images, labels in test_loader:
          images = images.to(device)
          labels = labels.to(device)
          output = model(images)
          test_loss += criterion(output, labels).item()
          _, predicted = torch.max(output,1)
          n_samples += labels.size(0)
          n_correct += (predicted == labels).sum().item()
          
          for i in range(2):
            label = labels[i]
            pred = predicted[i]
            if(label == pred):
              n_class_correct[label]+=1
            n_class_samples[label]+=1
          acc_list.append(n_correct/n_samples * 100.)
            

          
    test_loss /= len(test_loader)
    test_accuracy = (n_correct / n_samples) * 100.
    return test_loss, test_accuracy

# %%
model = models.resnet18(pretrained=False).cuda()
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)
model = model.cuda()

# %%
optimizer = torch.optim.Adam(model.parameters(), lr = 0.0001)
# print(model)

# %%
for EPOCH in range(EPOCHS):
    train(model, train_loader, optimizer, log_interval = 5)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH: {}], \tTest Loss: {:.4f}, \tTest Accuracy: {:.4f} %\n".format(EPOCH+1, test_loss, test_accuracy))
# Out:
# Train Epoch: 50 [0(0%)]	Train Loss : 0.589784
# Train Epoch: 50 [2000(31%)]	Train Loss : 0
%
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.009676
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.002780
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.125724
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.000895
#
# [EPOCH: 28], 	Test Loss: 0.4058, 	Test Accuracy: 87.9805 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.000613
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.003311
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.184156
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.001787
#
# [EPOCH: 29], 	Test Loss: 0.3587, 	Test Accuracy: 88.6516 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.001579
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.004444
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.023256
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.056365
#
# [EPOCH: 30], 	Test Loss: 0.3006, 	Test Accuracy: 90.9091 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.031229
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.000679
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.001429
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.016308
#
# [EPOCH: 31], 	Test Loss: 0.3362, 	Test Accuracy: 89.9939 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.002351
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.000170
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.060600
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.003957
#
# [EPOCH: 32], 	Test Loss: 0.4282, 	Test Accuracy: 88.8957 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.246647
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.022070
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.006302
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.000145
#
# [EPOCH: 33], 	Test Loss: 0.4113, 	Test Accuracy: 89.5058 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.003257
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.010455
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.007368
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.000143
#
# [EPOCH: 34], 	Test Loss: 0.4235, 	Test Accuracy: 88.1635 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.003258
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.001254
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.006578
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.000305
#
# [EPOCH: 35], 	Test Loss: 0.4457, 	Test Accuracy: 87.7974 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.000533
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.000403
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.000210
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.000435
#
# [EPOCH: 36], 	Test Loss: 0.3733, 	Test Accuracy: 89.5668 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.000308
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.000318
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.004722
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.000459
#
# [EPOCH: 37], 	Test Loss: 0.3932, 	Test Accuracy: 90.0549 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.005445
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.000849
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.001282
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.000340
#
# [EPOCH: 38], 	Test Loss: 0.3891, 	Test Accuracy: 89.4448 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.033178
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.046643
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.000204
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.040949
#
# [EPOCH: 39], 	Test Loss: 0.3299, 	Test Accuracy: 90.0549 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.002457
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.000347
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.002744
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.020547
#
# [EPOCH: 40], 	Test Loss: 0.3944, 	Test Accuracy: 90.9091 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.005213
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.000089
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.005827
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.000123
#
# [EPOCH: 41], 	Test Loss: 0.3200, 	Test Accuracy: 90.1159 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.002054
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.000336
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.001482
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.008203
#
# [EPOCH: 42], 	Test Loss: 0.3953, 	Test Accuracy: 89.6888 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.000062
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.000727
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.000897
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.000102
#
# [EPOCH: 43], 	Test Loss: 0.3898, 	Test Accuracy: 90.2379 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.001043
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.000218
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.000312
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.001375
#
# [EPOCH: 44], 	Test Loss: 0.4566, 	Test Accuracy: 87.0043 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.000913
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.000145
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.000152
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.002610
#
# [EPOCH: 45], 	Test Loss: 0.4764, 	Test Accuracy: 88.6516 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.000752
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.018329
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.043189
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.001479
#
# [EPOCH: 46], 	Test Loss: 0.3559, 	Test Accuracy: 90.6040 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.004084
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.000098
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.002046
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.002190
#
# [EPOCH: 47], 	Test Loss: 0.3571, 	Test Accuracy: 89.8719 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.000405
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.005745
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.000411
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.001015
#
# [EPOCH: 48], 	Test Loss: 0.3749, 	Test Accuracy: 89.6888 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.000174
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.013833
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.066317
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.003086
#
# [EPOCH: 49], 	Test Loss: 0.3712, 	Test Accuracy: 90.9091 %
#
# Train Epoch: 50 [0(0%)]	Train Loss : 0.000071
# Train Epoch: 50 [2000(31%)]	Train Loss : 0.000044
# Train Epoch: 50 [4000(61%)]	Train Loss : 0.014435
# Train Epoch: 50 [6000(92%)]	Train Loss : 0.000238
#
# [EPOCH: 50], 	Test Loss: 0.3514, 	Test Accuracy: 90.8481 %

# %%
plt.figure(figsize=(10,5))
plt.plot(loss_list)
plt.xlabel('Train size')
plt.ylabel('Loss')
plt.title('Train Loss of the ResNet18 without pretrained, epoch = 50')
plt.legend
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(acc_list)
plt.xlabel('Test size')
plt.ylabel('Accuracy')
plt.title('Test Accuracy of the ResNet18 without pretrained, epoch = 50')
plt.legend
plt.show()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
