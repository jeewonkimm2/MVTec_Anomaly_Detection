# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import DataLoader, random_split, ConcatDataset
from torchvision.utils import save_image
import numpy as np
import matplotlib.pyplot as plt
import os
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

BATCH_SIZE = 4
EPOCHS = 20
# Out:
# cuda

# %%
# Tensor -1~1 change
# transform = transforms.Compose(
#     [transforms.Resize((1000,1000)),
#     transforms.ToTensor(),
#      transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))]
# )

transform = transforms.Compose(
    [transforms.Resize((224,224)),
    transforms.ToTensor(),
     transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))]
)


# Data Load
image_dataset = torchvision.datasets.ImageFolder(root="/home/iai/Desktop/Jeewon/Seminar/20230112_MVtecAD/data/simpleclassification_good_bad_aug/dataset", transform = transform)
print(f'Entire classes : {image_dataset.classes}')
print(f'Size of Entire classes : {len(image_dataset)}')
# Out:
# Entire classes : ['bad', 'good']
# Size of Entire classes : 8192

# %%
train_size = int(0.8 * len(image_dataset))
test_size = len(image_dataset) - train_size

train_dataset, test_dataset = random_split(image_dataset, [train_size, test_size])


print(f'Size of entire dataset : {len(image_dataset)}')
print(f'Size of train dataset : {len(train_dataset)}')
print(f'Size of train dataset : {len(test_dataset)}')

train_loader = DataLoader(train_dataset, batch_size = BATCH_SIZE, shuffle = True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size = BATCH_SIZE, shuffle = False, num_workers=2)


def imshow(img):
    img = img / 2 + 0.5
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)))
    plt.show()
# Out:
# Size of entire dataset : 8192
# Size of train dataset : 6553
# Size of train dataset : 1639

# %%
dataiter = iter(train_loader)
images, labels = next(dataiter)

imshow(torchvision.utils.make_grid(images))
print(images.shape)
# Out:
# torch.Size([4, 3, 224, 224])

# %%
dataiter = iter(test_loader)
images, labels = next(dataiter)

imshow(torchvision.utils.make_grid(images))
print(images.shape)
# Out:
# torch.Size([4, 3, 224, 224])

# %%
criterion = nn.CrossEntropyLoss()

loss_list = []

def train(model, train_loader, optimizer, log_interval):
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(device)
        label = label.to(device)
        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()
        loss_list.append(loss.item())

        
        if batch_idx % 500 == 0:
            print("Train Epoch: {} [{}({:.0f}%)]\tTrain Loss : {:.6f}".format(
                EPOCHS, batch_idx * len(image), 100. * batch_idx / len(train_loader), loss.item()
            ))

# %%
acc_list = []
accuracy = 0.0

def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    # correct = 0
    
    with torch.no_grad():
      n_correct = 0
      n_samples = 0
      n_class_correct = [0 for i in range(2)]
      n_class_samples = [0 for i in range(2)]
      for images, labels in test_loader:
          images = images.to(device)
          labels = labels.to(device)
          output = model(images)
          test_loss += criterion(output, labels).item()
          _, predicted = torch.max(output,1)
          n_samples += labels.size(0)
          n_correct += (predicted == labels).sum().item()
          
          for i in range(2):
            label = labels[i]
            pred = predicted[i]
            if(label == pred):
              n_class_correct[label]+=1
            n_class_samples[label]+=1
          acc_list.append(n_correct/n_samples * 100.)
            

          
    test_loss /= len(test_loader)
    test_accuracy = (n_correct / n_samples) * 100.
    return test_loss, test_accuracy

# %%
model = models.resnet18(pretrained=False).cuda()
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)
model = model.cuda()

# %%
optimizer = torch.optim.Adam(model.parameters(), lr = 0.0001)
# print(model)

# %%
for EPOCH in range(EPOCHS):
    train(model, train_loader, optimizer, log_interval = 5)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH: {}], \tTest Loss: {:.4f}, \tTest Accuracy: {:.4f} %\n".format(EPOCH+1, test_loss, test_accuracy))
# Out:
# Train Epoch: 20 [0(0%)]	Train Loss : 0.969264
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.707911
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.456144
# Train Epoch: 20 [6000(92%)]	Train Loss : 0.956800
#
# [EPOCH: 1], 	Test Loss: 0.5909, 	Test Accuracy: 63.4533 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 1.011835
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.648359
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.471771
# Train Epoch: 20 [6000(92%)]	Train Loss : 0.543730
#
# [EPOCH: 2], 	Test Loss: 0.6072, 	Test Accuracy: 62.4161 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 0.662317
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.590926
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.880139
# Train Epoch: 20 [6000(92%)]	Train Loss : 0.893947
#
# [EPOCH: 3], 	Test Loss: 0.5802, 	Test Accuracy: 68.0293 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 0.590540
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.841669
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.356393
# Train Epoch: 20 [6000(92%)]	Train Loss : 1.003764
#
# [EPOCH: 4], 	Test Loss: 0.4931, 	Test Accuracy: 76.4491 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 0.427070
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.320733
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.945273
# Train Epoch: 20 [6000(92%)]	Train Loss : 0.773077
#
# [EPOCH: 5], 	Test Loss: 0.5852, 	Test Accuracy: 71.0799 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 1.081029
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.175446
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.418153
# Train Epoch: 20 [6000(92%)]	Train Loss : 0.490367
#
# [EPOCH: 6], 	Test Loss: 0.4559, 	Test Accuracy: 77.1202 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 0.296543
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.297525
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.068680
# Train Epoch: 20 [6000(92%)]	Train Loss : 0.161951
#
# [EPOCH: 7], 	Test Loss: 0.4254, 	Test Accuracy: 79.3777 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 0.154884
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.062605
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.095999
# Train Epoch: 20 [6000(92%)]	Train Loss : 0.168552
#
# [EPOCH: 8], 	Test Loss: 0.4414, 	Test Accuracy: 79.3167 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 0.630568
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.131361
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.258728
# Train Epoch: 20 [6000(92%)]	Train Loss : 0.433258
#
# [EPOCH: 9], 	Test Loss: 0.3613, 	Test Accuracy: 84.6858 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 0.118624
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.299136
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.034861
# Train Epoch: 20 [6000(92%)]	Train Loss : 0.474875
#
# [EPOCH: 10], 	Test Loss: 0.3796, 	Test Accuracy: 83.0384 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 0.233998
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.036891
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.067096
# Train Epoch: 20 [6000(92%)]	Train Loss : 0.042524
#
# [EPOCH: 11], 	Test Loss: 0.3417, 	Test Accuracy: 86.6382 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 0.377642
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.036101
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.128184
# Train Epoch: 20 [6000(92%)]	Train Loss : 0.134548
#
# [EPOCH: 12], 	Test Loss: 0.3253, 	Test Accuracy: 87.3703 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 0.274628
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.082091
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.462633
# Train Epoch: 20 [6000(92%)]	Train Loss : 0.265400
#
# [EPOCH: 13], 	Test Loss: 0.3288, 	Test Accuracy: 85.2349 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 0.465049
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.063816
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.125734
# Train Epoch: 20 [6000(92%)]	Train Loss : 0.258627
#
# [EPOCH: 14], 	Test Loss: 0.3591, 	Test Accuracy: 86.4552 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 0.507245
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.003929
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.009268
# Train Epoch: 20 [6000(92%)]	Train Loss : 0.129161
#
# [EPOCH: 15], 	Test Loss: 0.3291, 	Test Accuracy: 87.5534 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 0.060742
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.398811
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.010251
# Train Epoch: 20 [6000(92%)]	Train Loss : 0.083426
#
# [EPOCH: 16], 	Test Loss: 0.3339, 	Test Accuracy: 87.3703 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 0.062275
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.152672
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.002308
# Train Epoch: 20 [6000(92%)]	Train Loss : 1.456253
#
# [EPOCH: 17], 	Test Loss: 0.4457, 	Test Accuracy: 84.6858 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 0.080453
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.036810
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.055141
# Train Epoch: 20 [6000(92%)]	Train Loss : 0.040573
#
# [EPOCH: 18], 	Test Loss: 0.3438, 	Test Accuracy: 87.1873 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 0.014376
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.022462
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.006386
# Train Epoch: 20 [6000(92%)]	Train Loss : 0.006522
#
# [EPOCH: 19], 	Test Loss: 0.3982, 	Test Accuracy: 88.1025 %
#
# Train Epoch: 20 [0(0%)]	Train Loss : 0.003549
# Train Epoch: 20 [2000(31%)]	Train Loss : 0.010595
# Train Epoch: 20 [4000(61%)]	Train Loss : 0.942866
# Train Epoch: 20 [6000(92%)]	Train Loss : 0.002934
#
# [EPOCH: 20], 	Test Loss: 0.3926, 	Test Accuracy: 86.3331 %

# %%
plt.figure(figsize=(10,5))
plt.plot(loss_list)
plt.xlabel('Train size')
plt.ylabel('Loss')
plt.title('Train Loss of the ResNet18 without pretrained, epoch = 20')
plt.legend
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(acc_list)
plt.xlabel('Test size')
plt.ylabel('Accuracy')
plt.title('Test Accuracy of the ResNet18 without pretrained, epoch = 20')
plt.legend
plt.show()
